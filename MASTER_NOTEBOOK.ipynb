# %% [markdown]
# <a href="https://colab.research.google.com/github/trofaiacher/dl-tensorflow-course/blob/main/MASTER_NOTEBOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/trofaiacher/dl-tensorflow-course.git
# %cd dl-tensorflow-course
# !pip install -r requirements.txt

# %%
# !python run.py
