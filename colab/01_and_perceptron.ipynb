# %% [markdown]
# <a href="https://colab.research.google.com/github/trofaiacher/dl-tensorflow-course/blob/main/colab/01_and_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, shutil

REPO_NAME = "dl-tensorflow-course"
REPO_URL  = "https://github.com/trofaiacher/dl-tensorflow-course.git"

if os.path.exists(REPO_NAME):
    shutil.rmtree(REPO_NAME)

# !git clone -q {REPO_URL} {REPO_NAME}
# %cd {REPO_NAME}
# Out:
# /content/dl-tensorflow-course

# %%
# %%capture
# !pip install -qq -r requirements.txt

# %%
# %%capture
# %cd examples/01_and_perceptron
# !python run.py

# %%
from PIL import Image
from IPython.display import display

display(Image.open("and_misclassifications.png"))
display(Image.open("and_decision_boundary.png"))
