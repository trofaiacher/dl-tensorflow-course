# %% [markdown]
# <a href="https://colab.research.google.com/github/trofaiacher/dl-tensorflow-course/blob/main/colab/01_mnist_mlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, shutil

REPO = "dl-tensorflow-course"  # falls dein Repo-Ordner anders heißt: anpassen
URL  = "https://github.com/<DEIN-USERNAME>/<DEIN-REPO>.git"

if os.path.exists(REPO):
    shutil.rmtree(REPO)

# !git clone {URL} {REPO}
# %cd {REPO}
# !pip install -q -r requirements.txt

# %%
# %cd examples/01_mnist_mlp
# !python run.py
