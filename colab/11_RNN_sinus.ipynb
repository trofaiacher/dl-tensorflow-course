# %% [markdown]
# <a href="https://colab.research.google.com/github/trofaiacher/dl-tensorflow-course/blob/main/colab/11_RNN_sinus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, shutil

REPO_NAME = "dl-tensorflow-course"
REPO_URL  = "https://github.com/trofaiacher/dl-tensorflow-course.git"

if os.path.exists(REPO_NAME):
    shutil.rmtree(REPO_NAME)

# !git clone -q {REPO_URL} {REPO_NAME}
# %cd {REPO_NAME}
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'dl-tensorflow-course': No such file or directory
# [Errno 2] No such file or directory: 'dl-tensorflow-course'
# /content/dl-tensorflow-course/examples/11_RNN_sinus/dl-tensorflow-course

# %%
# %%capture
# !pip install -qq -r requirements.txt

# %%
# %%capture
EXAMPLE = "11_RNN_sinus"
# %cd examples/{EXAMPLE}
# !python run.py
