# %% [markdown]
# <a href="https://colab.research.google.com/github/trofaiacher/dl-tensorflow-course/blob/main/01_and_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, shutil

REPO_NAME = "dl-tensorflow-course"
REPO_URL  = "https://github.com/trofaiacher/dl-tensorflow-course.git"

if os.path.exists(REPO_NAME):
    shutil.rmtree(REPO_NAME)

# !git clone {REPO_URL} {REPO_NAME}
# %cd {REPO_NAME}
# !pip install -q -r requirements.txt
# Out:
# Cloning into 'dl-tensorflow-course'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 166 (delta 9), reused 0 (delta 0), pack-reused 138 (from 1)
# Receiving objects: 100% (166/166), 54.86 KiB | 3.92 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /content/dl-tensorflow-course
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 60.5 MB/s eta 0:00:00

# %%
# %cd examples/01_and_perceptron
# !python run.py
# Out:
# /content/dl-tensorflow-course/examples/01_and_perceptron
# 2026-02-27 12:53:22.068414: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772196802.093873    1667 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772196802.101198    1667 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772196802.121063    1667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772196802.121123    1667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772196802.121128    1667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772196802.121133    1667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-27 12:53:29.105093: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Saved: and_misclassifications.png
# Saved: and_decision_boundary.png
# Done.

# %%
from PIL import Image
from IPython.display import display

display(Image.open("and_misclassifications.png"))
display(Image.open("and_decision_boundary.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1609x1176>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1634x1638>
