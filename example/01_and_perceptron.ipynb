# %% [markdown]
# <a href="https://colab.research.google.com/github/trofaiacher/dl-tensorflow-course/blob/main/example/01_and_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil

REPO_NAME = "dl-tensorflow-course"
REPO_URL  = "https://github.com/trofaiacher/dl-tensorflow-course.git"

# Remove old copy if it exists (prevents nested folders)
if os.path.exists(REPO_NAME):
    shutil.rmtree(REPO_NAME)

# Clone fresh version
# !git clone {REPO_URL} {REPO_NAME}

# %cd {REPO_NAME}

# Install dependencies (quietly)
# !pip install -q -r requirements.txt

print("Repository ready.")

# %%
# %cd examples/01_and_perceptron
# !python run.py
